# %% [markdown]
# # Welcome to Python !

# %% [markdown]
# We use this notebook to give you a short introduciton to using Python in the lab.
#
# Python is a very interesting and detailed programming language. **We do not expect you to learn Python from these notebooks.** Luckily, you will not need to actually program new code for EN1.
#
# In our practicals, we use Python as our data analysis language. Therefore, you need not to program Python for EN1; you need to do data analysis in Python! We will show you how to do this in these notebooks; you can re-use them for your own experiments, or copy our code.
#
# After working through this notebook, you will be able to do the following things in Python:
#
# * Print lines of text and variables to the screen
# * Create variables and assign values
# * Create lists of variables called arrays
# * Manipulate arrays
# * Plot data
# * Save figures to use in lab journals and reports

# %% [markdown]
# # What is Jupyter?
#
# Before we get started first some information about using Jupyter notebooks. The notebook consists of
# different blocks of python code which we call *cells*. Using the arrow keys you can select a cell.
#
# We have already filled out most of the cells. For every topic, we give you a mini exercise to test your understanding.
# To edit the contents of a cell click somewhere in the code of the cell.
#
# To execute the code in a cell, select the cell and press <b>SHIFT+Enter</b>.
#
# <i>All keyboard shortcuts can be found by pressing the small keyboard in the menu bar. Many of these functions are also accessible using the mouse and the menu bar. Moving the cursor to a function and pressing shift+tab gives information about the function.</i>

# %% [markdown]
# # Python syntax
# With the "syntax" of a programming language we mean the "grammar" of that language. The grammar of Python is incredibly simple! A Python program consists of lines. Every line is an instruction to the computer, like "make a nice graph" or "multiply all my data values by five". Some instructions are easier than others. The easiest instruction is the "print" instruction: this writes a bit of text to the screen.
#
# This first cell of code prints a sentence to the screen. Select the cell, then press <b>SHIFT+Enter</b> to run it.

# %%
print("I am learning Python!")
# Out:
# I am learning Python!

# %% [markdown]
# We use quotes like this: "I am learning Python!" to indicate a bit of text.
#
# ### Test your understanding:
# In the empty cell below, write Python code to print the sentence *I like physics!*

# %% [markdown]
# # Variables
# We can attach a name to numbers, just like we do in mathematics. We then talk about *variables*.
#
# In Python we can assign a value to a variable by using the = sign. Here we assign numerical values to the variables $a$ and $b$. We can also use mathematical operators on new variables and assign the result to a new variable.
#
# Look at the new cell. What do you expect to happen? Select the cell, then press <b>SHIFT+Enter</b> to run it.

# %%
a=3
b=5

c=a+b
d=a*c
a=d*b
e=b**2 #This is the notation for b to the power of 2

print("a = \t", a) # \t is the TAB character
print("d = \t", d)
print("e = \t", e)
# Out:
# a = 	 120
# d = 	 24
# e = 	 25

# %% [markdown]
# ### Test your understanding:
# In the empty cell below, make a variable $x$ with value $5$. Make a variable $y$ which is just $x^2+2x$. Print $y$. What do you expect to see? Does it work as expected?

# %% [markdown]
# # Adding functionality with modules
# So far, we have only used Python as a nice calculator. But Python can do so much more! We want to use Python to manipulate experimental data, and to make nice graphs.
#
# By itself, Python cannot do all those things. If it could, the language would become too big to manage. After all, not everyone needs to make nice graphs!
#
# This extra functionality is provided by various packages, which we call modules. You need to "import" these packages once per program, and then you can use them!
#
# We do this in the next cell. Do not worry if you don't really understand this. Again, after doing this once (per program), you do not need to think about it anymore! You will learn what this means during your Python course. Don't forget to read the comments for some explanation.
#
# Run the next cell to import all the modules we need for now.

# %%
import numpy as np  # Numpy stands for "Numerical Python". It contains all the nice codes for manipulating data.
                    # Numpy is the fundamental package for scientific computing with Python: http://numpy.org/
                    # Numpy provides support to mathematically manipulate large, multi-dimensional arrays and matrices.
                    # By importing numpy "as np", we make sure that all numpy-related functions have np. in front of 
                    # them like this: np.function()
import matplotlib.pyplot as plt # Matplotlib.pyplot gives you code to make pretty graphs!
                                # Throughout your studies you will most likely use matplotlib.pyplot 
                                # to plot any graph you need to illustrate your research
                                # By importing pyplot "as plt", we make sure that all pyplot-related functions have 
                                # plt. in front of them like this: plt.function()

# %% [markdown]
# ### Documentation
# If you are ever looking for functions, it would be wise to explore the accompanying websites: http://numpy.org/ & https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html.

# %% [markdown]
# # Arrays
# We can also assign more complex forms of data to a variable. Experimental data often consists of lists of values. Every entrance in this list then corresponds to a single measurement.
#
# In Python, those lists are implemented in NumPy as objects called "arrays". Let's make a simple array containing the values 1, 2 and 3:

# %%
x=np.array([1, 2, 3])
print(x)
# Out:
# [1 2 3]

# %% [markdown]
# Using the function np.arange we can create an ordered, evenly spaced list of numbers. The function np.arange takes three arguments: a starting value, a stop value and a stepsize. For more information, read the documentation:  https://docs.scipy.org/doc/numpy/reference/generated/numpy.arange.html

# %%
x = np.arange(1, 10, 2)
print(x)
# Out:
# [1 3 5 7 9]

# %% [markdown]
# ### Test your understanding:
# In the empty cell below, make an array $x$ with all numbers from 1 through 100, by making use of the np.arange function. In the documentation, look up the function np.linspace. Rewrite your code, without np.arange and with np.linspace.

# %% [markdown]
# # Manipulating arrays
# Just like with regular variables we can apply mathematical operators to an array. The operators are then applied to every single entry of the array.

# %%
y=2*x+3
print(y)

y2=x**2
z = y + y2
print(y2)
print(z)
# Out:
# [-1.70000000e+01 -1.69599600e+01 -1.69199199e+01 -1.68798799e+01
#  -1.68398398e+01 -1.67997998e+01 -1.67597598e+01 -1.67197197e+01
#  -1.66796797e+01 -1.66396396e+01 -1.65995996e+01 -1.65595596e+01
#  -1.65195195e+01 -1.64794795e+01 -1.64394394e+01 -1.63993994e+01
#  -1.63593594e+01 -1.63193193e+01 -1.62792793e+01 -1.62392392e+01
#  -1.61991992e+01 -1.61591592e+01 -1.61191191e+01 -1.60790791e+01
#  -1.60390390e+01 -1.59989990e+01 -1.59589590e+01 -1.59189189e+01
#  -1.58788789e+01 -1.58388388e+01 -1.57987988e+01 -1.57587588e+01
#  -1.57187187e+01 -1.56786787e+01 -1.56386386e+01 -1.55985986e+01
#  -1.55585586e+01 -1.55185185e+01 -1.54784785e+01 -1.54384384e+01
#  -1.53983984e+01 -1.53583584e+01 -1.53183183e+01 -1.52782783e+01
#  -1.52382382e+01 -1.51981982e+01 -1.51581582e+01 -1.51181181e+01
#  -1.50780781e+01 -1.50380380e+01 -1.49979980e+01 -1.49579580e+01
#  -1.49179179e+01 -1.48778779e+01 -1.48378378e+01 -1.47977978e+01
#  -1.47577578e+01 -1.47177177e+01 -1.46776777e+01 -1.46376376e+01
#   69.52265879  69.8520773   70.18229741  70.51331912  70.84514244
#   71.17776736  71.51119388  71.845422    72.18045172  72.51628305
#   72.85291598  73.19035051  73.52858664  73.86762438  74.20746372
#   74.54810466  74.8895472   75.23179135  75.5748371   75.91868445
#   76.2633334   76.60878396  76.95503612  77.30208988  77.64994524
#   77.99860221  78.34806077  78.69832094  79.04938272  79.40124609
#   79.75391107  80.10737765  80.46164583  80.81671561  81.172587
#   81.52925999  81.88673458  82.24501078  82.60408857  82.96396797
#   83.32464897  83.68613158  84.04841578  84.41150159  84.775389
#   85.14007802  85.50556863  85.87186085  86.23895467  86.60685009
#   86.97554712  87.34504575  87.71534598  88.08644781  88.45835124
#   88.83105628  89.20456292  89.57887116  89.95398101  90.32989246
#   90.7066055   91.08412016  91.46243641  91.84155427  92.22147373
#   92.60219479  92.98371745  93.36604172  93.74916759  94.13309506
#   94.51782413  94.90335481  95.28968708  95.67682097  96.06475645
#   96.45349353  96.84303222  97.23337251  97.6245144   98.0164579
#   98.409203    98.8027497   99.197098    99.5922479   99.98819941
#  100.38495252 100.78250723 101.18086355 101.58002146 101.97998098
#  102.3807421  102.78230483 103.18466915 103.58783508 103.99180261
#  104.39657175 104.80214248 105.20851482 105.61568876 106.0236643
#  106.43244145 106.8420202  107.25240055 107.6635825  108.07556606
#  108.48835121 108.90193797 109.31632634 109.7315163  110.14750787
#  110.56430104 110.98189581 111.40029218 111.81949016 112.23948974
#  112.66029092 113.08189371 113.50429809 113.92750408 114.35151167
#  114.77632087 115.20193166 115.62834406 116.05555806 116.48357366
#  116.91239087 117.34200968 117.77243009 118.2036521  118.63567572
#  119.06850093 119.50212775 119.93655618 120.3717862  120.80781783
#  121.24465106 121.68228589 122.12072232 122.55996036 123.        ]

# %% [markdown]
# ### Test your understanding:
# Make an array $I$ containing all even numbers between $1$ and $100$. Make an array $R$ containing all uneven numbers between $1$ and $100$. Make an array $V = IR$. What do you expect the elements of $V$ to be? Print the array to test your expectations.

# %% [markdown]
# # Plotting data
# Instead of printing the data, we can also plot the data in a graph. For this we use the function plt.plot (which is part of the matplotlib.pyplot package that we imported in the first cell)

# %%
x = np.linspace(-10, 10, 1000)
y = np.linspace(-10, 10, 1000)
z = x + y
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7e6d798e8b52> in <module>()
# ----> 1 x = np.linspace(-10, 10, 1000)
#       2 y = np.linspace(-10, 10, 1000)
#       3 z = x + y
#       4 plt.plot(x,y)
#
# NameError: name 'np' is not defined

# %% [markdown]
# We can make the plot nicer by adding labels, a title and a caption.

# %%
plt.plot(x,y)

plt.xlabel("x (unit of x)")
plt.ylabel("y (unit of y)")
plt.title('y vs x')
# Out:
# Text(0.5,1,'y vs x')

# %% [markdown]
# We can add extra graphs, by calling the plot function again.

# %%
plt.plot(x,y)

plt.plot(x,z)

plt.xlabel("x (unit of x)")
plt.ylabel("y (unit of y)")
plt.title('Plot of y & z vs x')

plt.text(0,0,"Just above here to the left is where the 2 graphs touch!")
# Out:
# Text(0,0,'Just above here to the left is where the 2 graphs touch!')

# %% [markdown]
# Adding a legend takes some extra work.

# %%
# Labels are added for each graph so they can be used in the legend.
plt.plot(x,y, label='straight')
plt.plot(x,z, label='curved')
plt.xlabel("x (unit of x)")
plt.ylabel("y (unit of y)")
plt.title('Plot of y & z vs x')
#plt.text(0,0,"Just above here to the left is where the 2 graphs touch!")

# Add a legend to the figure.
plt.legend()

# %% [markdown]
# When you start using Python in a program instead of a notebook like this is and you want to create a new figure you can use plt.figure().

# %%
#Plotting the earlier diagram
plt.figure()
# The label is to be used in the legend.
plt.plot(x,y, label='straight')
plt.plot(x,z, label='curved')
plt.xlabel("x (unit of x)")
plt.ylabel("y (unit of y)")
plt.title('Plot of y & z vs x')
#plt.text(0,0,"Just above here to the left is where the 2 graphs touch!")

# Add a legend to the figure.
plt.legend()

#Making another diagram
plt.figure()
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,z)
plt.xlabel("x (unit of x)")
plt.ylabel("y (unit of y)")
plt.title('Plot of y, y2 & z vs x')
# Out:
# Text(0.5,1,'Plot of y, y2 & z vs x')

# %% [markdown]
# ### Test your understanding:
# Make a nice graph of a parabola $y = x^2$. Attach a legend and axis labels.

# %% [markdown]
# # Save figures
# The current figure can be saved by using plt.savefig. The image format is derived from the file extension (that is so easy!).<BR>
# <i>The file is stored in the folder where the notebook is being executed, unless otherwise specified.</i>

# %%
#plt.figure()
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,z)
plt.xlabel("x (unit of x)")
plt.ylabel("y (unit of y)")
plt.title('Plot of y, y2 & z vs x')

plt.savefig("My-pretty-plot.png", bbox_inches='tight')
plt.savefig("My-pretty-plot.pdf", bbox_inches='tight')
#bbox='tight' makes sure that the caption is incorporated in the image that is saved.

# %% [markdown]
# ### Test your understanding:
# In the last exercise you plotted a parabola. Save the parabola to disk!

# %% [markdown]
# <h3>Extra: add timestamp and user data!</h3>
# It is common practice to add timestamp data and userdata to the names of the figures.

# %%
#plt.figure()
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,z)
plt.xlabel("x (unit of x)")
plt.ylabel("y (unit of y)")
plt.title('Plot of y, y2 & z vs x')
#plt.figtext(0,-0.1,'Figure #.. Plot of y, y2 & z vs x.\nNotice the spots where the three graphs touch or intersect!')
# Putting \n in the text makes sure that the subsequent text is put on a new line.

# Usually we want our filenames to be timestamped!
# Make sure that we get date and time into the filename properly.
time = str(datetime.now())
#print(now)
timeformatted = time.replace(":","-")[0:19]
#print(nowformatted)
space = " "
filename = "My-pretty-plot"
usernames = "s2019007 & s2019008"
fullfilename = timeformatted + space + filename + space + usernames
dir = "p:/"
extension1 = ".png"
extension2 = ".pdf"
plt.savefig(fullfilename + extension1, bbox_inches='tight')
plt.savefig(dir + fullfilename + extension2, bbox_inches='tight')
# bbox_inches='tight' makes sure that the caption is incorporated in the image that is saved.

# %% [markdown]
# # If you want to re-use this notebook in your experiment, add cells below:

# %%
# Your code here: try plotting an interesting function for yourself
